# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshatBajpai4218/NLP/blob/main/ner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Named Entity Recognition (NER) with spaCy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
text = "Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in 1976. Its headquarters are in Cupertino, California. The company released the first iPhone in 2007."
doc = nlp(text)

print("Detected Entities:")
for ent in doc.ents:
    print(f"  - {ent.text} ({ent.label_})")
# Out:
# Detected Entities:
#   - Apple Inc. (ORG)
#   - Steve Jobs (PERSON)
#   - Steve Wozniak (PERSON)
#   - Ronald Wayne (PERSON)
#   - 1976 (DATE)
#   - Cupertino (GPE)
#   - California (GPE)
#   - first (ORDINAL)
#   - 2007 (DATE)

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Wozniak
# ...
